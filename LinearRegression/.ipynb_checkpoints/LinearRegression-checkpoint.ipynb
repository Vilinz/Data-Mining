# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import pandas as pd
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

# %%
class LinearRegression(nn.Module):
    def __init__(self):
        super(LinearRegression, self).__init__()
        self.fc = nn.Linear(1, 1)
        
    def forward(self, x):
        output = self.fc(x)
        return output

# %%
class PointDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.frame = pd.read_csv(csv_file, encoding='utf-8', header=0)
        self.transform = transform
        
    def __len__(self):
        return len(self.frame)
    
    def __getitem__(self, idx):
        x = np.array(self.frame.iloc[idx, 0])
        y = np.array(self.frame.iloc[idx, 1])
        if self.transform is not None:
            x = self.transform(x).float()
            y = self.transform(y).float()
        sample = {'x':x,'y':y}
        return sample

# %%
def train(network, trainloader, device, optimeter):
    epoches = 100
    criterion = torch.nn.MSELoss(size_average=False).to(device)
    optimizer = optimeter
    for i in range(epoches):
        print('epoche', i)
        for j, data in enumerate(trainloader):
            x = data['x'].to(device)
            x = x.view(x.size(0), -1)
            y = data['y'].to(device)
            output = network(x)
            loss = criterion(output, y)
            print('loss', loss.item())
            optimeter.zero_grad()
            
            loss.backward()
            optimizer.step()

# %%
transform = torch.tensor
device = torch.device('cuda:0')
trainset = PointDataset('./Salary_Data.csv', transform=transform)
trainloader = DataLoader(dataset=trainset,batch_size=len(trainset))
network = LinearRegression().to(device)

optimizer = torch.optim.SGD(network.parameters(), lr=0.01)

train(network, trainloader, device, optimizer)
# Out:
# epoche 0
# loss 5853013344256.0
# epoche 1
# loss 1.804209795616473e+18
# epoche 2
# loss 7.873184942233757e+23
# epoche 3
# loss 3.435705977475158e+29
# epoche 4
# loss 1.499276114042744e+35
# epoche 5
# loss inf
# epoche 6
# loss inf
# epoche 7
# loss inf
# epoche 8
# loss inf
# epoche 9
# loss inf
# epoche 10
# loss inf
# epoche 11
# loss inf
# epoche 12
# loss inf
# epoche 13
# loss nan
# epoche 14
# loss nan
# epoche 15
# loss nan
# epoche 16
# loss nan
# epoche 17
# loss nan
# epoche 18
# loss nan
# epoche 19
# loss nan
# epoche 20
# loss nan
# epoche 21
# loss nan
# epoche 22
# loss nan
# epoche 23
# loss nan
# epoche 24
# loss nan
# epoche 25
# loss nan
# epoche 26
# loss nan
# epoche 27
# loss nan
# epoche 28
# loss nan
# epoche 29
# loss nan
# epoche 30
# loss nan
# epoche 31
# loss nan
# epoche 32
# loss nan
# epoche 33
# loss nan
# epoche 34
# loss nan
# epoche 35
# loss nan
# epoche 36
# loss nan
# epoche 37
# loss nan
# epoche 38
# loss nan
# epoche 39
# loss nan
# epoche 40
# loss nan
# epoche 41
# loss nan
# epoche 42
# loss nan
# epoche 43
# loss nan
# epoche 44
# loss nan
# epoche 45
# loss nan
# epoche 46
# loss nan
# epoche 47
# loss nan
# epoche 48
# loss nan
# epoche 49
# loss nan
# epoche 50
# loss nan
# epoche 51
# loss nan
# epoche 52
# loss nan
# epoche 53
# loss nan
# epoche 54
# loss nan
# epoche 55
# loss nan
# epoche 56
# loss nan
# epoche 57
# loss nan
# epoche 58
# loss nan
# epoche 59
# loss nan
# epoche 60
# loss nan
# epoche 61
# loss nan
# epoche 62
# loss nan
# epoche 63
# loss nan
# epoche 64
# loss nan
# epoche 65
# loss nan
# epoche 66
# loss nan
# epoche 67
# loss nan
# epoche 68
# loss nan
# epoche 69
# loss nan
# epoche 70
# loss nan
# epoche 71
# loss nan
# epoche 72
# loss nan
# epoche 73
# loss nan
# epoche 74
# loss nan
# epoche 75
# loss nan
# epoche 76
# loss nan
# epoche 77
# loss nan
# epoche 78
# loss nan
# epoche 79
# loss nan
# epoche 80
# loss nan
# epoche 81
# loss nan
# epoche 82
# loss nan
# epoche 83
# loss nan
# epoche 84
# loss nan
# epoche 85
# loss nan
# epoche 86
# loss nan
# epoche 87
# loss nan
# epoche 88
# loss nan
# epoche 89
# loss nan
# epoche 90
# loss nan
# epoche 91
# loss nan
# epoche 92
# loss nan
# epoche 93
# loss nan
# epoche 94
# loss nan
# epoche 95
# loss nan
# epoche 96
# loss nan
# epoche 97
# loss nan
# epoche 98
# loss nan
# epoche 99
# loss nan
